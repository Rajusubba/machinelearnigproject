# %%
import sys
print(sys.path)
# Out:
# ['/Users/rajusubba/Documents/MLOpsProject/machinelearningproject/venv/lib/python311.zip', '/Users/rajusubba/Documents/MLOpsProject/machinelearningproject/venv/lib/python3.11', '/Users/rajusubba/Documents/MLOpsProject/machinelearningproject/venv/lib/python3.11/lib-dynload', '', '/Users/rajusubba/Documents/MLOpsProject/machinelearningproject/venv/lib/python3.11/site-packages']
